# %%
import numpy as np
import time

# %%
start = time.time()
ar = []
sum = 0
for i in range(0, 1000000):
    sum += i
    ar.append(i)

print(sum)
end = time.time()
print(end - start)
# Out:
# 499999500000
# 0.5403592586517334

# %%
start = time.time()

br = np.arange(0, 1000000)
summ = br.sum()

end = time.time()
print(br)
print(su)
print(end - start)
# Out:
# [     0      1      2 ... 999997 999998 999999]
# 1783293664
# 0.006980419158935547

# %%
alpha = np.arange(1000000)

# %%
alplha
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-48e683569d27> in <module>
# ----> 1 alplha
#
# NameError: name 'alplha' is not defined

# %%
alpha
# Out:
# array([     0,      1,      2, ..., 999997, 999998, 999999])

# %%
val = np.sum(alpha)
print(val)
# Out:
# 1783293664

# %% [markdown]
# np.intersect1d(np1, npar)

# %% [markdown]
# 8235109079

# %% [markdown]
# PDF se phone number and email read krna hai

# %%
import tensorflow as tf
import tensorflow.keras
import torch

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce MX150'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Projects/data/ansur_male.csv')

# %%
df.shape
# Out:
# (4082, 99)

# %%
# Removing all the non_numeric columns from the dataset

non_numeric = ['BMI_class', 'Height_class', 'Gender', 
               'Component', 'Branch']

df_numeric = df.drop(non_numeric, axis=1)

df_numeric.shape
# Out:
# (4082, 94)

# %%
# Import TSNE from sklearn library 
from sklearn.manifold import TSNE

# Initialize the object
m = TSNE(learning_rate = 50)

# %%
# Fit the model
tsne_features = m.fit_transform(df_numeric)

# Checking the first 3 rows generated by TSNE
tsne_features[1:4, :]
# Out:
# array([[ -2.9009507,  28.946676 ],
#        [ -7.575021 , -15.886383 ],
#        [-38.13823  ,  23.239464 ]], dtype=float32)

# %%
df['x'] = tsne_features[:, 0]
df['y'] = tsne_features[:, 1]

# %%
# Import seaborn
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(x='x', y='y', data=df, alpha=0.6)
plt.show()

# %%
sns.scatterplot(x='x', y='y', hue='BMI_class', data=df, alpha=0.6)
plt.show()

# %%
sns.scatterplot(x='x', y='y', hue='Height_class', data=df, alpha=0.6)
plt.show()
